# %%
import numpy as np
import pandas as pd
np.random.seed(44)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tableau_20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),
         (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),
         (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),
         (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),
         (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]

        #São os dados, pode ler a tebela direto, só add a coluna

# %%
for i in range(len(tableau_20)):
    r, g, b = tableau_20[i]
    tableau_20[i] = (r / 255., g / 255., b / 255.)

    #Para Mudar as cores

# %%
tips = sns.load_dataset('tips')
tips.head()
#para verificar a tabela e saber qual dado quer realizar o Boxplot
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
#Plotar o Boxplot

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips, palette="coolwarm")

# %%
iris = sns.load_dataset("iris")
sns.boxplot(data=iris, orient ='h', palette='Set2')
#alterar a orientação

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips, color=tableau_20[7])
#Boxplot com pontos
